# %%
import requests
import pandas as pd

#Labeling API url

url = "https://api.census.gov/data/2022/acs/acs5"


#API Key, Columns/Variables of Interest, By county
url1 = {
    "get": "NAME,B08303_001E,B08303_012E,B08303_013E,B15003_001E,B15003_022E,B19013_001E",
    "for": "county:*",
    "key": "62e7098927e44aacb2ec1516548c851363a0635f"
}
print(url1)
# Out:
# /Users/mkaltenberg/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# {'get': 'NAME,B08303_001E,B08303_012E,B08303_013E,B15003_001E,B15003_022E,B19013_001E', 'for': 'county:*', 'key': '62e7098927e44aacb2ec1516548c851363a0635f'}

# %%
response = requests.get(url, url1=url1)

data = response.json()

#Creating the DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Converting to numerical form
cols = df.columns[1:-2]
df[cols] = df[cols].apply(pd.to_numeric)

data
# Out:
# -----------------------------------------------------------------------
# TypeError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response = requests.get(url, url1=url1)
#       3 data = response.json()
#       5 #Creating the DataFrame
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# TypeError: request() got an unexpected keyword argument 'url1'

# %%
# creating the variable for those who have long commute times: "Workers commuting 60–89 minutes" + "Workers commuting 90+ minutes" / Total workers

df["long_commute"] = (
    df["B08303_012E"] + df["B08303_013E"]
) / df["B08303_001E"]

# percentage of adults with college degrees: "Number of people with a Bachelor’s degree" / Total population (25+ years old)
df["college_rate"] = df["B15003_022E"] / df["B15003_001E"]


#creating an index of economic mobility - college rate * median income 
df["mobility_index"] = df["college_rate"] * df["B19013_001E"]

df.columns
# Out:
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 # creating the variable for those who have long commute times: "Workers commuting 60–89 minutes" + "Workers commuting 90+ minutes" / Total workers
#       3 df["long_commute"] = (
# ----> 4     df["B08303_012E"] + df["B08303_013E"]
#       5 ) / df["B08303_001E"]
#       7 # percentage of adults with college degrees: "Number of people with a Bachelor’s degree" / Total population (25+ years old)
#       8 df["college_rate"] = df["B15003_022E"] / df["B15003_001E"]
#
# NameError: name 'df' is not defined

# %%
#Created Organized Dataset
data = df[["NAME","state", "long_commute", "college_rate", "mobility_index"]]

data
# Out:
#                                   NAME state  long_commute  college_rate  \
# 0              Autauga County, Alabama    01      0.072026      0.167363
# 1              Baldwin County, Alabama    01      0.079995      0.200417
# 2              Barbour County, Alabama    01      0.104908      0.066025
# 3                 Bibb County, Alabama    01      0.097382      0.065746
# 4               Blount County, Alabama    01      0.175782      0.094078
# ...                                ...   ...           ...           ...
# 3217  Vega Baja Municipio, Puerto Rico    72      0.094379      0.191654
# 3218    Vieques Municipio, Puerto Rico    72      0.000000      0.067475
# 3219   Villalba Municipio, Puerto Rico    72      0.122248      0.176550
# 3220    Yabucoa Municipio, Puerto Rico    72      0.114061      0.149398
# 3221      Yauco Municipio, Puerto Rico    72      0.035707      0.211329
#
#       mobility_index
# 0       11433.430128
# 1       14237.402773
# 2        2622.003055
# 3        3331.268006
# 4        5403.866036
# ...              ...
# 3217     4542.399267
# 3218     1151.266744
# 3219     3965.492370
# 3220     2983.770814
# 3221     4190.021306
#
# [3222 rows x 5 columns]

# %% [markdown]
# Good choice of new variables.
#
# Need some checks that the data seems reasonable and nothing strange. Can you get fips codes or some code names for the county?  Maybe add some other controls like race, age and other demographics?
#
# Grade: 95
